# %% [markdown]
# # MITF Regulon Expansion Across Cancer Types
# ## Expanding the Metabolic Regulon of MITF
# This notebook addresses **Priority 1** (Step 3) from the AI Summary (Version 5). \
# **Purpose**: Assess MITF binding across the 1,669 metabConnectomeDB target universe using ChEA 2022 ChIP-Seq data. \
# **Interpretation**: Reveals whether MITF controls a broader metabolic network active in non-melanoma cancers.

# %% [markdown]
# ### Inputs / Parameters
# *Explicitly documented for traceability and reproducibility.*
#
# **Configuration Files:**
# - `pan_cancer_config.py`

# %%
import pandas as pd
output_base = 'mitf_regulon' 
import sys
import os

# Find repo root
if os.path.basename(os.getcwd()) == 'scripts':
    REPO_ROOT = os.path.dirname(os.getcwd())
else:
    REPO_ROOT = os.getcwd()

if REPO_ROOT not in sys.path: sys.path.append(REPO_ROOT)
from pan_cancer_config import ANALYSIS_SUFFIX
output_filename="mitf_metabolic_regulon_pairs"+ANALYSIS_SUFFIX+ ".csv"
# Load output
mitf_out = os.path.join(REPO_ROOT, "output", output_base, output_filename)
if os.path.exists(mitf_out):
    df = pd.read_csv(mitf_out)
    display(df.head())
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metabolite_Name</th>
#       <th>Target</th>
#       <th>HMDB_ID</th>
#       <th>Sensor_Gene</th>
#       <th>Protein_Name</th>
#       <th>Evidence</th>
#       <th>OtherDB_Sensor_Type</th>
#       <th>database</th>
#       <th>Evidence_Score</th>
#       <th>Text_Evidence</th>
#       <th>blood_concentration</th>
#       <th>Secondary_HMDB_ID</th>
#       <th>Kegg_ID</th>
#       <th>Organ and components</th>
#       <th>Cell and elements</th>
#       <th>Tissue and substructures</th>
#       <th>Biofluid and excreta</th>
#       <th>Subcellular</th>
#       <th>Kingdom</th>
#       <th>Class</th>
#       <th>associated_gene</th>
#       <th>Software_Predicted</th>
#       <th>BioLocation_Summary</th>
#       <th>Receptor_Gene_Symbol</th>
#       <th>Transporter</th>
#       <th>Enzyme</th>
#       <th>Task</th>
#       <th>transmembrane</th>
#       <th>peripheral</th>
#       <th>secreted</th>
#       <th>secreted_desc</th>
#       <th>secreted_highlight</th>
#       <th>receptor</th>
#       <th>integrin</th>
#       <th>other</th>
#       <th>other_desc</th>
#       <th>pdb_structure</th>
#       <th>comments_complex</th>
#       <th>reactome_reaction</th>
#       <th>reactome_complex</th>
#       <th>rhea_reaction</th>
#       <th>curator</th>
#       <th>...</th>
#       <th>Receptor_Uniprot</th>
#       <th>PMID</th>
#       <th>Other.DB</th>
#       <th>HMDB_Protein_ID</th>
#       <th>Enzyme_Full_Name</th>
#       <th>Human_geneID</th>
#       <th>Protein_Uniprot</th>
#       <th>REACTIONS</th>
#       <th>OtherDB_enzyme product/substrate</th>
#       <th>OtherDB_Interaction</th>
#       <th>Cell type</th>
#       <th>Experimental subject</th>
#       <th>Disease</th>
#       <th>Effect</th>
#       <th>Effect_detail</th>
#       <th>Target_Gene</th>
#       <th>scCellFie_value</th>
#       <th>System</th>
#       <th>Subsystem</th>
#       <th>ensembl_id</th>
#       <th>sccellfie_threshold</th>
#       <th>Super_Class</th>
#       <th>Sub_Class</th>
#       <th>Target_original</th>
#       <th>Target_Uniprot</th>
#       <th>databases_count</th>
#       <th>HMDB_Name</th>
#       <th>SMILES</th>
#       <th>INCHIKEY</th>
#       <th>CHEMICAL_FORMULA</th>
#       <th>AVERAGE_MASS</th>
#       <th>MONO_MASS</th>
#       <th>Rhea_enzyme product/substrate</th>
#       <th>KEGG_enzyme product/substrate</th>
#       <th>GtoPdb_Sensor_Type</th>
#       <th>HGNC_Sensor_Type</th>
#       <th>UniProt_Sensor_Type</th>
#       <th>Reactions_enzyme product/substrate</th>
#       <th>GtoPdb_Interaction</th>
#       <th>Sensor_Type</th>
#       <th>enzyme product/substrate</th>
#       <th>Interaction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>(r)-5-diphosphomevalonic acid</td>
#       <td>PMVK</td>
#       <td>HMDB0001090</td>
#       <td>PMVK</td>
#       <td>Phosphomevalonate kinase | phosphomevalonate k...</td>
#       <td>Cellinker</td>
#       <td>Enzyme</td>
#       <td>Cellinker2, MEBOCOST, MRCLinkDB</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>HMDB01090</td>
#       <td>C01143</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Peroxisome : Peroxisome vesicle - Peroxisomal</td>
#       <td>Organic compounds</td>
#       <td>Organic oxoanionic compounds</td>
#       <td>MVD; PMVK</td>
#       <td>Compass</td>
#       <td>Other</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>Q15126</td>
#       <td>17902708</td>
#       <td>IUPHAR/BPS</td>
#       <td>HMDBP01016 | HMDBP01017</td>
#       <td>Diphosphomevalonate decarboxylase | Phosphomev...</td>
#       <td>10654.0 | 4597.0</td>
#       <td>P53602 | Q15126</td>
#       <td>Adenosine triphosphate + (R)-5-Diphosphomevalo...</td>
#       <td>p | s</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Organic oxygen compounds</td>
#       <td>Organic pyrophosphates</td>
#       <td>PMVK</td>
#       <td>Q15126</td>
#       <td>3</td>
#       <td>(R)-5-Diphosphomevalonic acid</td>
#       <td>C[C@@](O)(CCOP(O)(=O)OP(O)(O)=O)CC(O)=O</td>
#       <td>SIGQQUBJQXSAMW-ZCFIWIBFSA-N</td>
#       <td>C6H14O10P2</td>
#       <td>308.1169</td>
#       <td>308.006220</td>
#       <td>NaN</td>
#       <td>product</td>
#       <td>Enzyme</td>
#       <td>Enzyme</td>
#       <td>Enzyme</td>
#       <td>s+p</td>
#       <td>Inhibit</td>
#       <td>Enzyme</td>
#       <td>s+p</td>
#       <td>Inhibit</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>(r)-lipoic acid</td>
#       <td>ICAM1</td>
#       <td>HMDB0001451</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>MetaLigand</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Fatty acids</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Lipids and lipid-like molecules</td>
#       <td>NaN</td>
#       <td>ICAM1</td>
#       <td>P05362</td>
#       <td>1</td>
#       <td>(R)-Lipoic acid</td>
#       <td>OC(=O)CCCC[C@@H]1CCSS1</td>
#       <td>AGBQKNBQESQNJD-SSDOTTSWSA-N</td>
#       <td>C8H14O2S2</td>
#       <td>206.3260</td>
#       <td>206.043521</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Receptor</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Receptor</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1-methylhistamine</td>
#       <td>HRH3</td>
#       <td>HMDB0000898</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>MetaLigand</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>organic amino compound</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

if os.path.exists(mitf_out) and 'Metabolite_Name' in df.columns:
    plt.figure(figsize=(10,6))
    top_metabolites = df['Metabolite_Name'].value_counts().head(15)
    sns.barplot(y=top_metabolites.index, x=top_metabolites.values, palette='viridis')
    plt.title('Top 15 Metabolites Interacting with MITF Transcriptional Targets')
    plt.xlabel('Number of Target Genes')
    plt.ylabel('Metabolite')
    plt.show()
